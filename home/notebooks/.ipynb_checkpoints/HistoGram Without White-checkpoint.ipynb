# %%
import PIL.ImageOps
from PIL import Image

# %%
i = Image.open("sitsang/rope/865562.jpeg")

# %%
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=222x230 at 0x7FD370733EB8>

# %%
i2 = PIL.ImageOps.equalize(i)

# %%
from matplotlib import pyplot as plt
i2
# Out:
# <PIL.Image.Image image mode=RGB size=222x230 at 0x7FD37079A8D0>

# %%
w, h = i2.size  
color1 = i.getcolors(w*h)
color2 = i2.getcolors(w*h)

# %%
import pandas as pd

def getHisto(c):
    return (pd.DataFrame( list(map(lambda x:(int((x[1][0]+x[1][1]+x[1][2])/3),x[0]), c)))).groupby([0]).sum().reset_index()

# %%
df1 = getHisto(color1)
df2 = getHisto(color2)

# %%
plt.close
plt.bar(data1[0].tolist(),data1[1].tolist())
plt.show()
plt.close
plt.bar(data2[0].tolist(),data2[1].tolist())
plt.show()
